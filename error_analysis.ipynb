# %%
import json
import pandas as pd
from utils import handle_reproducibility, preprocess
import unicodedata

# %%
with open('data/qa/processed_train_150_r2_pg0.json', 'r') as f1:
    qa_data = json.load(f1)

# %%
gt_data_dir = 'qa_pred_test/gt.csv'
pred_data_dir = 'qa_pred_test/qa_c3_1.csv'

# %%
gt = pd.read_csv(gt_data_dir)
pred = pd.read_csv(pred_data_dir)

# %%
gt["answer"] = gt["answer"].apply(lambda text: unicodedata.normalize("NFKC", text))

# %%
gt.head()
# Out:
#     id answer
# 0  657      A
# 1  658      C
# 2  121      A
# 3  122      B
# 4  632      C

# %%
pred.head()
# Out:
#     id answer
# 0  657      A
# 1  658      C
# 2  121      A
# 3  122      A
# 4  632      C

# %% [markdown]
# ## General Statistics

# %% [markdown]
# accuracy

# %%
sum(gt['answer'] == pred['answer'])/len(pred)
# Out:
# 0.6142857142857143

# %% [markdown]
# ration of neg and positive questions

# %%
all_qas = []
for _id in gt['id'].values:
    all_qas.append(qa_data[_id - 1])

all_neg_qas = 0
for qa in all_qas:
    question = qa['question']['stem']
    if '誤' in question or '不' in question or '沒' in question:
        all_neg_qas +=1
print(f"neg Q: {all_neg_qas}; pos Q: {len(pred) - all_neg_qas}")
# Out:
# neg Q: 45; pos Q: 25

# %% [markdown]
# ## Wrong questions analysis

# %% [markdown]
# Hypothesis 1: neg Qs are harder to answer

# %%
wrong_pred = pred[gt['answer'] != pred['answer']]
wrong_ids = wrong_pred['id'].values
wrong_ans = wrong_pred['answer'].values

# %%
wrong_qas = []
for _id in wrong_ids:
    wrong_qas.append(qa_data[_id - 1])

# %%
wrong_neg_qa = 0
for i, qa in enumerate(wrong_qas):
    question = qa['question']['stem']
    if '誤' in question or '不' in question or '沒' in question:
        wrong_neg_qa +=1
print(f"neg Q: {wrong_neg_qa}; pos Q: {len(wrong_qas) - wrong_neg_qa}")
# Out:
# neg Q: 18; pos Q: 9

# %%
print(f"neg Q wrong ratio: {round(wrong_neg_qa/all_neg_qas, 2)}")
print(f"pos Q wrong ratio: {round((len(wrong_qas) - wrong_neg_qa)/(len(pred) - all_neg_qas), 2)}")
# Out:
# neg Q wrong ratio: 0.4
# pos Q wrong ratio: 0.36

# %% [markdown]
# ## Wrong question types

# %% [markdown]
# - enough information too hard: 203, 672, 675(講錯)
# - enough information but wrong: 122, 440， 312, '172'(neg Q), 505(來回改變), 509, 29, 409, 393, 217, 285, 142, 143, 500, 262, 39
# - not enough info: 634, 313, 394, 216, 194, 676(太少), 624

# %%
for i, qa in enumerate(wrong_qas):
    print('——————————————————————————————————————————————————————————————————————-')
    question = qa['question']['stem']
    print(qa['id'])
    print(qa['text'])
    print(qa['question']['stem'])
    print(qa['question']['choices'])
    print(f"gt: {qa['answer']} pred: {wrong_ans[i]}")
# Out:
# ——————————————————————————————————————————————————————————————————————-
# 122
# 個管師:嗯哼,然後你那時候有想過說,誒其實你自己可以來試試看嗎?民眾:因為那時候,基本上應該是很少,就是跟不認識的人做性行為,所以就比較少,想說誒好像還好。個管師:所以你現在固,就是有固砲?民眾:恩。個管師:然後你這個固砲多久了?民眾:前後應該半年多了吧。個管師:但你都只有跟他,你沒有再約,還是你有固砲但也有約?民眾:就約的話就是沒有打,沒有打砲。個管師:那其它工作忙沒有辦法請假,那我可能沒有辦法回來,沒有關係你不用太緊張。民眾:所以回診一樣都要是禮拜三跟禮拜五這兩個時間?
# 下列關於民眾的性關係，何者錯誤？
# [{'text': '有固砲', 'label': 'A'}, {'text': '半年多，沒有打砲', 'label': 'B'}, {'text': '很少，跟不認識的人做性行為', 'label': 'C'}]
# gt: Ｂ pred: A
# ——————————————————————————————————————————————————————————————————————-
# 634
# 醫師:你有看到就亮亮的。好,啊另外就是,肝臟的部分,肝臟的部分就是,這邊,還有這個地方顯影也比較明顯,可能可以反映出你肝發炎指數高。民眾:嗯。醫師:所以不是跟你開刀的地方。民眾:又不一樣?醫師:不過確實啦,你那時候應該⋯好吧應該就⋯民眾:骨頭那天在做的時候反而是類似種肩膀的這邊,他叫我抬高,我有點,這個肩膀會痛。醫師:還可以接受。民眾:對。可是你是胸椎啊。胸椎可能,會不會是因為肺部那個東西造成的。
# 請問何者不是醫師建議民眾追蹤的地方？
# [{'text': '肩膀', 'label': 'A'}, {'text': '肝臟', 'label': 'B'}, {'text': '肺部', 'label': 'C'}]
# gt: Ａ pred: C
# ——————————————————————————————————————————————————————————————————————-
# 440
# 醫師:好,今天,今天還沒打嘛?民眾:好很多很多了。真的要感謝你。你給我,那個讓,讓我可以在⋯不必住院。真的,不然我沒有那個,我的體質你知道的。醫師:那你先生還有繼續再看診嗎?民眾:我先生一天要看幾個。醫師:哇!那很多勒。那他有預約的還是一來就看這樣子?民眾:預約。醫師:對啊,很快就知道重點。民眾:他也比較快知道重點。啊,林醫師,我真的這一次要感謝你。
# 下列關於此次看診的敘述，何者錯誤?
# [{'text': '民眾很感謝醫師', 'label': 'A'}, {'text': '民眾有B肝', 'label': 'B'}, {'text': '民眾要住院', 'label': 'C'}]
# gt: C pred: B
# ——————————————————————————————————————————————————————————————————————-
# 312
# 醫師:因為照理說那個藥物治療,尿道感染應該人就會比較舒服這樣。但是還是吃不下,燒是有加特別退燒的。家屬:嗯。醫師:嘿啊,那是很好的藥了。民眾:嘿啊,那他為什麼還是燒到三十八度?醫師:我們就是帳會分開記,因為結核菌是衛生局出錢,啊,啊那個尿道感染是那個。家屬:啊血壓他有比較正常。醫師:喔,他,哪一科?民眾:有一顆比較強的那一顆,一百八那一次的。醫師:以前不是這樣子。民眾:對啊,以前不是,啊我們那個中醫師說他是,就是生病,就人太虛。醫師:嗯嗯。家屬:是怕說他吃這個後又開始又不吃,啊衛生所說你有什麼,有比較好的那個可以開胃的藥,有嗎?可是那個是胃藥。
# 何者不是目前民眾的症狀?
# [{'text': '發燒', 'label': 'A'}, {'text': '尿道感染', 'label': 'B'}, {'text': '有痰', 'label': 'C'}]
# gt: C pred: A
# ——————————————————————————————————————————————————————————————————————-
# 313
# 醫師:欸,他應該不至於,那個藥很好的藥捏。民眾:那個已經很好的藥了。醫師:嘿啊,那是很好的藥了。民眾:嘿啊,那他為什麼還是燒到三十八度?醫師:是啊,沒辦法啊。那我結核菌的藥開他,我們還是讓他試試看嗎?還是,讓他吃吃看好不好?家屬:嗯。醫師:是啊,二線藥那個有的毒性更強。你有沒有帶結核菌的簿子?家屬:沒有,它都還沒補給我。
# 何者不是醫師開給民眾的藥?
# [{'text': '開胃的藥', 'label': 'A'}, {'text': '營養針', 'label': 'B'}, {'text': '結核菌', 'label': 'C'}]
# gt: B pred: C
# ——————————————————————————————————————————————————————————————————————-
# 194
# 醫師:6組,所以意思是大概是每個周末,每個禮拜,還是不一定周末,平常日都會?民眾:對,不一定是周末。醫師:哦,就是每個禮拜都會可能會有一次這樣子?民眾:嗯。醫師:然後所以是跟你這個固定的伴侶,還是有可能跟,還是你們分手了?民眾:分手了。醫師:ok,所以大部分還是會戴保險套,還是大部分不會戴?民眾:基本上都會。醫師:那保險套你是自己會戴,還是飯店裏面,你通常都約哪裏?民眾:我通常都自己買。醫師:好哦,好啦,不過就是,所以有曾經在這個過程中有使用過一些其他的藥品或什麽等等的?民眾:沒有。
# 下列關於民眾的敘述是錯誤的？
# [{'text': '大部分還是會戴保險套', 'label': 'A'}, {'text': '有固定的伴侶', 'label': 'B'}, {'text': '每個禮拜都會可能會有一次', 'label': 'C'}]
# gt: C pred: B
# ——————————————————————————————————————————————————————————————————————-
# 172
# 醫師:五月,那你現在還是天天吃嗎?民眾:對我是每天吃。醫師:所以連偶爾忘記都不太會?民眾:不會。醫師:哦~OKOK,還是你們是開放性關係嗎?民眾:不是。醫師:對,就是一年啦!啊你大概反正這本來就是差不多一年啦!民眾:那我想問一下,那個我找一下⋯肌酸酐是我太高嗎?這。醫師:恩亨,那這個可能就是要注意是沒有錯啦!因為標準是1.2啦!男生是設到1.2啊。民眾:那,有關跟喝酒有關係嗎?因為我真的就是每天喝酒。
# 下列敘述何者有誤?
# [{'text': '民眾是開放式關係', 'label': 'A'}, {'text': '民眾的肌酸酐太高', 'label': 'B'}, {'text': '民眾每天喝酒', 'label': 'C'}]
# gt: A pred: B
# ——————————————————————————————————————————————————————————————————————-
# 505
# 醫師:有喔,有在考慮。民眾:可是你那時候建議我說,如果你都已經吃習慣了。醫師:你就一回家,很想睡,就,就忘記了。那假如改成早上吃的藥呢?民眾:早上吃,你說醒來吃嗎?醫師:就是也是一天一次,但是醒來就一起吃這樣子。這樣對你會不會有幫忙?民眾:我覺得還是睡覺吃好了。
# 民眾決定藥要在哪時候吃？
# [{'text': '早上吃', 'label': 'A'}, {'text': '睡覺前吃', 'label': 'B'}, {'text': '早上跟睡覺前都吃', 'label': 'C'}]
# gt: B pred: A
# ——————————————————————————————————————————————————————————————————————-
# 509
# 醫師:啊頭?民眾:不會痛了。醫師:不會痛了,也不會暈了?民眾:不會暈了。醫師:三百的喔。這最低了啊,先這樣啦吼。民眾:啊腎臟這次比較不好。醫師:啊白血球這樣正常啦,啊缺血正常。啊這個藥跟肝比較有關係。民眾:喔肝,阿肝都⋯醫師:正常。民眾:喔,這種藥是和肝比較有關係喔。醫師:腎臟不好代謝比較慢。民眾:嗯嗯。
# 關於民眾的身體狀況下列何者錯誤?
# [{'text': '白血球正常', 'label': 'A'}, {'text': '頭還會痛', 'label': 'B'}, {'text': '腎臟代謝比較慢', 'label': 'C'}]
# gt: B pred: C
# ——————————————————————————————————————————————————————————————————————-
# 203
# 醫師:比如說我們HIV基本上還是要藉由比較是真的是10的事情,才比較容易會的得啦。民眾:嗯。醫師:那但是,呃,以梅毒來說我覺得,比方說就口交來說啦,我覺得以口交不太會得HIV,但是梅毒就很難講。民眾:嗯。
# 下列何者是性交方式容易得HIV？
# [{'text': '口交', 'label': 'A'}, {'text': '親吻', 'label': 'B'}, {'text': '10', 'label': 'C'}]
# gt: C pred: A
# ——————————————————————————————————————————————————————————————————————-
# 104
# 個管師:都有,好,所以你現在是沒有固定伴侶?民眾:現在算有。個管師:好喔那這個是交友軟體認識的嗎,還是朋友介紹?民眾:對。個管師:交友軟體認識的,好喔那,所以你現在有新的,所以你都在約,你會開始約砲了,然後只是說現在這一個比較固定?民眾:對。個管師:是他決定要不要戴套這件事,還是你決定要不要戴套這件事?民眾:嗯,嗯,我會盡量跟他說就是戴啦。個管師:知道,那我想問一下,就是你在吃PrEP之前沒有戴套,跟你現在吃了PrEP之後⋯。民眾:是。個管師:如果真的會有不戴套的時候,你比較不會那麼擔心會被感染?民眾:恩。
# 下列敘述何者有誤?
# [{'text': '民眾之前有在約炮', 'label': 'A'}, {'text': '民眾偶爾不會戴套', 'label': 'B'}, {'text': '現在的是朋友介紹的', 'label': 'C'}]
# gt: C pred: B
# ——————————————————————————————————————————————————————————————————————-
# 672
# 醫師:眼睛呢?民眾:眼睛也⋯是一樣。醫師:抗生素。類固醇,類固醇進去這樣。民眾:嘿對。醫師:抗生素有效啦?吃藥⋯民眾:抗生素就比較有效。醫師:嘿阿你有再吃胃藥嗎?民眾:胃藥喔?那個⋯血壓裡面就有胃藥了阿。
# 醫師使用什麼方法治療民眾的眼睛？
# [{'text': '胃藥', 'label': 'A'}, {'text': '類固醇', 'label': 'B'}, {'text': '抗生素', 'label': 'C'}]
# gt: B pred: C
# ——————————————————————————————————————————————————————————————————————-
# 29
# 個管師:然後你接下來第一個月,我上次有跟你說接下來第一個月一定要每天吃。民眾:是。個管師:就是如果,假設真的今天不小心我本來,我晚上的9點要吃,可是我可能太累我提早睡覺了。民眾:嗯。個管師:隔天的早上再吃就好了?不用再吃兩顆。民眾:好。個管師:然後再來另外一個就是剛剛毛醫師有跟你講到因為這個藥物如果是你要每天吃的話連續吃7天才具保護力。民眾:嗯。
# 請問醫師建議民眾第一個月要如何吃藥？
# [{'text': '隔天的早上再吃', 'label': 'A'}, {'text': '一定要每天吃', 'label': 'B'}, {'text': '晚上的９點要吃', 'label': 'C'}]
# gt: B pred: A
# ——————————————————————————————————————————————————————————————————————-
# 409
# 醫師:啊裡面有沒有破皮?嘴巴裡面。民眾:嘴巴裡面沒有,可是只有嘴唇有而已。醫師:啊沒發燒吧?民眾:誒⋯他禮拜四最高到38.1,然後再來就沒有了。醫師:啊皮膚有沒有起疹子?民眾:也沒有餒,他全部身上都沒有。藥師:就是平常吃皮膚癢的那種抗過敏的藥啊。民眾:喔,除了抗組織胺,那兩顆就是抗皮膚過敏那種的?藥師:對啊,就是皮膚癢一般都會用的那個藥就對了。民眾:喔,好。藥師:啊是有效嗎?民眾:是有效啦,不過因為我現在回來門診,他是說,這樣子其實不好啦。藥師:不好喔,那沒辦法,他急啊。民眾:喔。藥師:是因為他急啊,醫師:對。民眾:然後發燒就是下午這邊打嘛。
# 民眾過敏沒有發生以下哪種症狀?
# [{'text': '起疹子', 'label': 'A'}, {'text': '嘴唇起水泡', 'label': 'B'}, {'text': '發燒', 'label': 'C'}]
# gt: A pred: C
# ——————————————————————————————————————————————————————————————————————-
# 393
# 醫師:喔,還不太適應齁。是拉肚子。民眾:收縮。醫師:啊所以是拉肚子還是?糊糊的。民眾:不算,沒有,很少很少。醫師:血壓嘛,血壓現在還好齁?民眾:應該還好。醫師:血壓,啊頭暈呢?民眾:還是會,啊但是這顆藥,好像沒有說比較好。醫師:有有有,他有。民眾:做胃鏡?醫師:你有做過?家屬:它是不是免費的啊?是四十歲以上。
# 民眾有下列哪些症狀？
# [{'text': '拉肚子', 'label': 'A'}, {'text': '頭暈', 'label': 'B'}, {'text': '血壓過高', 'label': 'C'}]
# gt: B pred: A
# ——————————————————————————————————————————————————————————————————————-
# 394
# 醫師:你坐那種,高爾夫那種喔?家屬:對對對。醫師:我也跑去做,做檢查。民眾:嗯嗯嗯。醫師:有有有,他有。民眾:做胃鏡?醫師:嘿,我們媽媽就知道。民眾:嘿啊。家屬:我是都沒有血便啦,都還好。大便都正常。
# 民眾的家屬選擇何種檢查？
# [{'text': '大腸鏡', 'label': 'A'}, {'text': '胃鏡', 'label': 'B'}, {'text': '血便', 'label': 'C'}]
# gt: A pred: B
# ——————————————————————————————————————————————————————————————————————-
# 216
# 醫師:嗯哼。所以他也是⋯比方說是像菜花那樣,還是像龜頭有發紅那樣。民眾:不是,就是像長菜花那樣。醫師:嗯哼,所以是怎麼樣決定甚麼時候要吃?民眾:之前就依照需求嘛,阿現在是,最近就是比較沒有⋯醫師:連性行為都沒有?民眾:就幾乎比較沒有。醫師:好啊那我就是一樣開愛滋跟梅毒。民眾:嗯。
# 民眾沒有下列何種疾病?
# [{'text': '梅毒', 'label': 'A'}, {'text': '菜花', 'label': 'B'}, {'text': '愛滋病', 'label': 'C'}]
# gt: C pred: B
# ——————————————————————————————————————————————————————————————————————-
# 217
# 醫師:好啦。那這個月還好嗎?民眾:就⋯狀態是還好,只是有HPV。醫師:還是你B看到的?民眾:我自己注意到的。醫師:嗯哼。所以他也是⋯比方說是像菜花那樣,還是像龜頭有發紅那樣。民眾:不是,就是像長菜花那樣。醫師:好,那原則上就是⋯所以你現在是,就是手上那些藥都還有在吃嗎?還是就沒有在吃了?民眾:痾⋯比較少。嗯。醫師:嗯哼,所以是怎麼樣決定甚麼時候要吃?民眾:之前就依照需求嘛,阿現在是,最近就是比較沒有⋯醫師:連性行為都沒有?民眾:就幾乎比較沒有。
# 下列敘述何者正確?
# [{'text': '民眾的B有菜花', 'label': 'A'}, {'text': '民眾有去電燒', 'label': 'B'}, {'text': '民眾最近比較沒有性行為', 'label': 'C'}]
# gt: B pred: C
# ——————————————————————————————————————————————————————————————————————-
# 285
# 醫師:現在吃了快超過一年了,有沒有什麽心得可以分享?民眾:心得哦。醫師:也就是比較安全,覺得,就是安全感有比較好一點。民眾:不會。醫師:還是覺得很擔心?民眾:對,反而更擔心。醫師:反而更擔心,爲什麽?民眾:因爲,因爲就反而是知道越多,反而是更難約。
# 請問民眾現在吃藥快超過一年，沒有什麽心得？
# [{'text': '反而更擔心', 'label': 'A'}, {'text': '反而是知道越多，反而是更難約', 'label': 'B'}, {'text': '安全感有比較好一點', 'label': 'C'}]
# gt: C pred: A
# ——————————————————————————————————————————————————————————————————————-
# 675
# 醫師:阿你B肝⋯你C肝已經治療好了。民眾:那還要再追蹤嗎?醫師:只有C肝而已?民眾:對,然後A肝沒有了嘛,A肝治療過了。醫師:然後看有沒有抗體阿,這些。然後超音波你今⋯今年剛做過嗎?民眾:對。
# 民眾沒得過下列何者病症？
# [{'text': 'A肝', 'label': 'A'}, {'text': 'B肝', 'label': 'B'}, {'text': 'C肝', 'label': 'C'}]
# gt: B pred: A
# ——————————————————————————————————————————————————————————————————————-
# 676
# 醫師:就抽血那幾天這樣。民眾:抽血前。醫師:抽血前這樣子。民眾:對。
# 民眾病毒量變高是因為下列何者原因？
# [{'text': '抽血前發燒', 'label': 'A'}, {'text': '抽血前拉肚子', 'label': 'B'}, {'text': '抽血前咳嗽', 'label': 'C'}]
# gt: A pred: B
# ——————————————————————————————————————————————————————————————————————-
# 142
# 個管師:然後他上個禮拜,11月底的時候,突然一個公文說,中央不發藥。就全台灣不只長庚,全台灣就是有PrEP的計畫,全部都是沒有藥了。民眾:喔。個管師:對啊所以我才會說叫你趕快早點來阿,我都幫,催大家早點來,因為最後一個不知道是誰啊,就大家搶藥的概念而已。民眾:了解。個管師:那沒有約的原因是?民眾:就是工作比較忙,然後就有沒有時間就⋯個管師:工作忙沒有時間?民眾:對。個管師:那個抽血費用,所以等下你去轉介中心繳費,不能用機器繳。民眾:轉介中心繳費,就是⋯個管師:所以這個要麻煩你簽名。民眾:喔這個要抽兩支血?
# 請問個管師為何建議民眾趕快來看診？
# [{'text': '中央不發藥', 'label': 'A'}, {'text': '工作比較忙', 'label': 'B'}, {'text': '抽血', 'label': 'C'}]
# gt: Ａ pred: B
# ——————————————————————————————————————————————————————————————————————-
# 143
# 個管師:好吧。然後我跟你說,你今天要驗藥物濃度。民眾:嗯。個管師:對對對。然後再來就是我剛剛跟你講,你今天要抽藥物濃度的部分。民眾:嗯。個管師:所以這個要麻煩你簽名。民眾:喔這個要抽兩支血?個管師:三支血。民眾:這麼多。
# 下列何者不是民眾今天要做的檢查？
# [{'text': '抽藥物濃度', 'label': 'A'}, {'text': '抽兩支血', 'label': 'B'}, {'text': '抽三支血', 'label': 'C'}]
# gt: Ｂ pred: A
# ——————————————————————————————————————————————————————————————————————-
# 624
# 醫師:還好齁。家屬:欸像那個⋯醫生像說他如果吃完的話他是不是要驗血說看他體內還有沒有結核菌?還是⋯醫師:他那個時候有裝那個人工的嗎?家屬:沒有餒,他說要把結核菌吃完再看情形。
# 請問要如何看體內還有沒有結核菌？
# [{'text': '要抽痰', 'label': 'A'}, {'text': '吃少一點', 'label': 'B'}, {'text': '要看血壓', 'label': 'C'}]
# gt: Ａ pred: B
# ——————————————————————————————————————————————————————————————————————-
# 500
# 醫師:喔喔比較低,血糖血糖還可以耶齁,啊有吃比較多嗎?胃口有比較好嗎?民眾:有好一點。醫師:發炎指數就是你細菌感染的時候在看的數值高低,你最高的時候是138。民眾:嗯。醫師:130,10以上就是紅字了啊,啊你現在是7.9,這樣是正常的,啊白血球呢也降下來正常了,你最高的時候是14600,啊慢慢降下來之後今天是4900。民眾:嗯。醫師:嘿,4900,欸我看一下,但是你的你的腎,你最近的水是不是喝比較少?有比較少?民眾:沒有欸,一天也是喝蠻多水的。醫師:可能抗生素,抗生素吃也會有點感覺,啊,肝我相信應該發炎會有改善,因為發炎指數他就降到正常。民眾:嗯。醫師:1200齁。民眾:1200到1500左右。
# 下列關於民眾的指數何者錯誤？
# [{'text': '發炎指數７', 'label': 'A'}, {'text': '白血球４９００', 'label': 'B'}, {'text': '血糖１２００', 'label': 'C'}]
# gt: C pred: A
# ——————————————————————————————————————————————————————————————————————-
# 262
# 醫師:恩,所以就是水分還是要補足。民眾:所以如果排尿量很少,他會有一些?醫師:比較容易感染。民眾:是比較容易會感染這樣子?醫師:比較容易感染,對,這就是一個活水的概念阿,因為你⋯你⋯你⋯你反正這個泌尿道通道就好,你就想像是一個水管嘛。民眾:恩。醫師:如果水流的很慢,那當然就比較容易會在這邊會有孳⋯孳生一些細菌。民眾:恩。醫師:可是這個水如果一直很快的這樣子在走,那通常比較不會有細菌留下來。民眾:OK,了解。醫師:恩,所以水分喝多對泌尿道感染是有幫忙的。民眾:OKOK。
# 請問關於泌尿道感染，下列何者錯誤？
# [{'text': '水分喝多對泌尿道感染是有幫忙的', 'label': 'A'}, {'text': '水如果一直很快的走，孳生一些細菌', 'label': 'B'}, {'text': '如果排尿量很少，比較容易感染', 'label': 'C'}]
# gt: B pred: C
# ——————————————————————————————————————————————————————————————————————-
# 39
# 個管師:對,所以一定要吃完一個course。民眾:恩哼。個管師:對,這樣才可以殺死這些病毒。民眾:恩。個管師:就是一定要戴套。民眾:那如果漏藥就是那一天⋯那一天有記得吃,但是有時候可能不小,忘記是早上吃還晚上吃。個管師:因為只要維持24小時內都有一顆藥就好了,一顆藥的濃度就好了。民眾:恩恩恩恩恩。個管師:我突然有想起的話就從兩顆開始吃。民眾:恩恩恩。
# 關於Prep吃法下列何者錯誤？
# [{'text': '只要維持24小時內都有兩顆藥就好了', 'label': 'A'}, {'text': '一定要吃完一個course才能殺死病毒', 'label': 'B'}, {'text': '如果漏藥突然有想起就從兩顆開始吃', 'label': 'C'}]
# gt: A pred: B
